# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset_original = pd.read_csv("WHO COVID-19 cases.csv")

# %%
df = dataset_original.copy()

# %%
df
# Out:
#       Date_reported Country_code      Country Continent WHO_region  New_cases  \
# 0        2020-01-05           AF  Afghanistan      Asia       EMRO        NaN
# 1        2020-01-12           AF  Afghanistan      Asia       EMRO        NaN
# 2        2020-01-19           AF  Afghanistan      Asia       EMRO        NaN
# 3        2020-01-26           AF  Afghanistan      Asia       EMRO        NaN
# 4        2020-02-02           AF  Afghanistan      Asia       EMRO        NaN
# ...             ...          ...          ...       ...        ...        ...
# 58555    2024-08-04           ZW     Zimbabwe    Africa       AFRO        1.0
# 58556    2024-08-11           ZW     Zimbabwe    Africa       AFRO        NaN
# 58557    2024-08-18           ZW     Zimbabwe    Africa       AFRO        NaN
# 58558    2024-08-25           ZW     Zimbabwe    Africa       AFRO        NaN
# 58559    2024-09-01           ZW     Zimbabwe    Africa       AFRO        NaN
#
# ...

# %%
#descriptive analysis 
df.head()
# Out:
#   Date_reported Country_code      Country Continent WHO_region  New_cases  \
# 0    2020-01-05           AF  Afghanistan      Asia       EMRO        NaN
# 1    2020-01-12           AF  Afghanistan      Asia       EMRO        NaN
# 2    2020-01-19           AF  Afghanistan      Asia       EMRO        NaN
# 3    2020-01-26           AF  Afghanistan      Asia       EMRO        NaN
# 4    2020-02-02           AF  Afghanistan      Asia       EMRO        NaN
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0         NaN                  0
# 1                 0         NaN                  0
# 2                 0         NaN                  0
# 3                 0         NaN                  0
# 4                 0         NaN                  0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58560 entries, 0 to 58559
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date_reported      58560 non-null  object
#  1   Country_code       58316 non-null  object
#  2   Country            58560 non-null  object
#  3   Continent          58560 non-null  object
#  4   WHO_region         54168 non-null  object
#  5   New_cases          39260 non-null  float64
#  6   Cumulative_cases   58560 non-null  int64
#  7   New_deaths         25084 non-null  float64
#  8   Cumulative_deaths  58560 non-null  int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 4.0+ MB

# %%
Countrys = df['Country'].unique()
Countrys
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia (Plurinational State of)',
#        'Bonaire, Saint Eustatius and Saba', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Chile', 'China', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', "Côte d'Ivoire",
#        'Croatia', 'Cuba', 'Curaçao', 'Cyprus', 'Czechia',
#        "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
# ...

# %%
#pace -->plan, analyze, construct and execute
#analyze step of pace framework

#using exploratory data analysis 1)discovery 2)structure 3)cleaning 4) joining 5)validate 6)present
#discovery

df_usa = df[df['Country'] == 'United States of America']

# %%
df_usa.reset_index()
# Out:
#      index Date_reported Country_code                   Country  \
# 0    55876    2020-01-05           US  United States of America
# 1    55877    2020-01-12           US  United States of America
# 2    55878    2020-01-19           US  United States of America
# 3    55879    2020-01-26           US  United States of America
# 4    55880    2020-02-02           US  United States of America
# ..     ...           ...          ...                       ...
# 239  56115    2024-08-04           US  United States of America
# 240  56116    2024-08-11           US  United States of America
# 241  56117    2024-08-18           US  United States of America
# 242  56118    2024-08-25           US  United States of America
# 243  56119    2024-09-01           US  United States of America
#
#          Continent WHO_region  New_cases  Cumulative_cases  New_deaths  \
# 0    North America       AMRO        NaN                 0         NaN
# ...

# %%
df_usa.describe()
# Out:
#           New_cases  Cumulative_cases    New_deaths  Cumulative_deaths
# count  1.730000e+02      2.440000e+02    236.000000       2.440000e+02
# mean   5.979007e+05      6.406987e+07   5072.936441       7.862310e+05
# std    7.772336e+05      4.027615e+07   5288.045349       4.039502e+05
# min    2.000000e+00      0.000000e+00      1.000000       0.000000e+00
# 25%    2.225790e+05      2.864565e+07   1399.500000       5.276875e+05
# 50%    3.876340e+05      8.085887e+07   2821.000000       9.904495e+05
# 75%    7.096370e+05      1.034368e+08   6908.500000       1.131847e+06
# max    5.650933e+06      1.034368e+08  23312.000000       1.197213e+06

# %%
import datetime as dt

df_usa['Date_reported'] = pd.to_datetime(df_usa['Date_reported'])
# Out:
# /var/folders/fq/fkp9z40x3h531t_m7kkc8dsc0000gn/T/ipykernel_9316/4169145966.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_usa['Date_reported'] = pd.to_datetime(df_usa['Date_reported'])

# %%
df_usa
# Out:
#       Date_reported Country_code                   Country      Continent  \
# 55876    2020-01-05           US  United States of America  North America
# 55877    2020-01-12           US  United States of America  North America
# 55878    2020-01-19           US  United States of America  North America
# 55879    2020-01-26           US  United States of America  North America
# 55880    2020-02-02           US  United States of America  North America
# ...             ...          ...                       ...            ...
# 56115    2024-08-04           US  United States of America  North America
# 56116    2024-08-11           US  United States of America  North America
# 56117    2024-08-18           US  United States of America  North America
# 56118    2024-08-25           US  United States of America  North America
# 56119    2024-09-01           US  United States of America  North America
#
#       WHO_region  New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# ...

# %%
df_usa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 244 entries, 55876 to 56119
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date_reported      244 non-null    datetime64[ns]
#  1   Country_code       244 non-null    object
#  2   Country            244 non-null    object
#  3   Continent          244 non-null    object
#  4   WHO_region         244 non-null    object
#  5   New_cases          173 non-null    float64
#  6   Cumulative_cases   244 non-null    int64
#  7   New_deaths         236 non-null    float64
#  8   Cumulative_deaths  244 non-null    int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 19.1+ KB

# %%
df_usa['Month'] = df_usa['Date_reported'].dt.month
# Out:
# /var/folders/fq/fkp9z40x3h531t_m7kkc8dsc0000gn/T/ipykernel_9316/743590141.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_usa['Month'] = df_usa['Date_reported'].dt.month

# %%
df_usa
# Out:
#       Date_reported Country_code                   Country      Continent  \
# 55876    2020-01-05           US  United States of America  North America
# 55877    2020-01-12           US  United States of America  North America
# 55878    2020-01-19           US  United States of America  North America
# 55879    2020-01-26           US  United States of America  North America
# 55880    2020-02-02           US  United States of America  North America
# ...             ...          ...                       ...            ...
# 56115    2024-08-04           US  United States of America  North America
# 56116    2024-08-11           US  United States of America  North America
# 56117    2024-08-18           US  United States of America  North America
# 56118    2024-08-25           US  United States of America  North America
# 56119    2024-09-01           US  United States of America  North America
#
#       WHO_region  New_cases  Cumulative_cases  New_deaths  Cumulative_deaths  \
# ...

# %%
df_by_month = df_usa.groupby(["Month"]).count().sort_values('Month',ascending = True).reset_index()

# %%
df_by_month
# Out:
#     Month  Date_reported  Country_code  Country  Continent  WHO_region  \
# 0       1             23            23       23         23          23
# 1       2             20            20       20         20          20
# 2       3             22            22       22         22          22
# 3       4             21            21       21         21          21
# 4       5             23            23       23         23          23
# 5       6             21            21       21         21          21
# 6       7             22            22       22         22          22
# 7       8             22            22       22         22          22
# 8       9             17            17       17         17          17
# 9      10             19            19       19         19          19
# 10     11             17            17       17         17          17
# 11     12             17            17       17         17          17
#
# ...

# %%
plt.bar(x = df_usa["Month"],height =df_usa["New_cases"],label = "New Cases in recorded in each month" )
# Out:
# <BarContainer object of 244 artists>

# %%
plt.bar(x = df_usa["Month"],height =df_usa["New_deaths"],label = "New deaths in recorded in each month" )
# Out:
# <BarContainer object of 244 artists>

# %%
df_usa['Year'] = df_usa['Date_reported'].dt.year
# Out:
# /var/folders/fq/fkp9z40x3h531t_m7kkc8dsc0000gn/T/ipykernel_9316/4257732092.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_usa['Year'] = df_usa['Date_reported'].dt.year

# %%
df_usa['Year']
# Out:
# 55876    2020
# 55877    2020
# 55878    2020
# 55879    2020
# 55880    2020
#          ...
# 56115    2024
# 56116    2024
# 56117    2024
# 56118    2024
# 56119    2024
# Name: Year, Length: 244, dtype: int32

# %%
plt.bar(x = df_usa["Year"],height =df_usa["New_deaths"],label = "New deaths in recorded in each Year" )
# Out:
# <BarContainer object of 244 artists>

# %%
df_usa_2021 = df_usa[df_usa['Year'] == 2021 ]

# %%
plt.bar(x = df_usa_2021["Month"],height =df_usa_2021["New_deaths"],label = "New deaths in recorded in each month" )
# Out:
# <BarContainer object of 52 artists>

# %%
df_usa_2021.reset_index()
# Out:
#     index Date_reported Country_code                   Country      Continent  \
# 0   55928    2021-01-03           US  United States of America  North America
# 1   55929    2021-01-10           US  United States of America  North America
# 2   55930    2021-01-17           US  United States of America  North America
# 3   55931    2021-01-24           US  United States of America  North America
# 4   55932    2021-01-31           US  United States of America  North America
# 5   55933    2021-02-07           US  United States of America  North America
# 6   55934    2021-02-14           US  United States of America  North America
# 7   55935    2021-02-21           US  United States of America  North America
# 8   55936    2021-02-28           US  United States of America  North America
# 9   55937    2021-03-07           US  United States of America  North America
# 10  55938    2021-03-14           US  United States of America  North America
# ...

# %%
plt.pie(df_usa_2021["New_deaths"],labels = df_usa_2021["Month"])
# Out:
# ([<matplotlib.patches.Wedge at 0x12fd5ab70>,
# ...
#  [Text(1.0905118370277351, 0.14416633900600687, '1'),
#   Text(1.0102874777232778, 0.4351082765881818, '1'),
#   Text(0.8367765449856982, 0.7140063121302206, '1'),
#   Text(0.5824377782472269, 0.9331485597001339, '1'),
#   Text(0.28141311272728525, 1.063393934525273, '1'),
#   Text(-0.02701909615320368, 1.0996681174077314, '2'),
#   Text(-0.3163491560848286, 1.0535289324192367, '2'),
#   Text(-0.5474662195343568, 0.9540863370097905, '2'),
#   Text(-0.7143784521322729, 0.8364588615880032, '2'),
#   Text(-0.8379741460210699, 0.7126004003649302, '3'),
#   Text(-0.9215570597358582, 0.600610177778399, '3'),
#   Text(-0.976484332524069, 0.5064369144671662, '3'),
#   Text(-1.015013886900626, 0.4239655757238828, '3'),
#   Text(-1.044507669103468, 0.3449691713530942, '4'),
#   Text(-1.0656960235792832, 0.2725655615210845, '4'),
#   Text(-1.0812318210062395, 0.20233079163471782, '4'),
#   Text(-1.0919834129296935, 0.13256027265519144, '4'),
# ...

# %%
df_2021 = df_usa_2021.groupby(df_usa_2021['Month']).sum([df_usa_2021['New_deaths']])
df_2021
# Out:
#        New_cases  Cumulative_cases  New_deaths  Cumulative_deaths   Year
# Month
# 1      6972587.0         116396021    109203.0            2036013  10105
# 2      2467058.0         110305569     67730.0            1990630   8084
# 3      1602108.0         117332240     31380.0            2165512   8084
# 4      1779222.0         124237015     19851.0            2255520   8084
# 5      1193501.0         162629515     20075.0            2918390  10105
# 6       366941.0         132563722      9162.0            2388833   8084
# 7       965153.0         135139315      7241.0            2418625   8084
# 8      4291462.0         182686948     31255.0            3113461  10105
# 9      4056569.0         164685828     50768.0            2678923   8084
# 10     3054638.0         222721594     55144.0            3622104  10105
# 11     2336661.0         188217270     30902.0            3057373   8084
# 12     3902514.0         200629996     36956.0            3190629   8084

# %%
#structure
''' 1) data formats
    2)gather
    3)seperate
    4)filter
    5)group
    '''
ds = df_usa
ds
# Out:
#       Date_reported Country_code                   Country      Continent  \
# 55876    2020-01-05           US  United States of America  North America
# 55877    2020-01-12           US  United States of America  North America
# 55878    2020-01-19           US  United States of America  North America
# 55879    2020-01-26           US  United States of America  North America
# 55880    2020-02-02           US  United States of America  North America
# ...             ...          ...                       ...            ...
# 56115    2024-08-04           US  United States of America  North America
# 56116    2024-08-11           US  United States of America  North America
# 56117    2024-08-18           US  United States of America  North America
# 56118    2024-08-25           US  United States of America  North America
# 56119    2024-09-01           US  United States of America  North America
#
#       WHO_region  New_cases  Cumulative_cases  New_deaths  Cumulative_deaths  \
# ...

# %%
data = ds[['Date_reported','New_cases','Cumulative_cases','New_deaths','Cumulative_deaths','Month','Year']]

# %%
data.reset_index(inplace = True)

# %%
data.drop_duplicates()
# Out:
#      index Date_reported  New_cases  Cumulative_cases  New_deaths  \
# 0    55876    2020-01-05        NaN                 0         NaN
# 1    55877    2020-01-12        NaN                 0         NaN
# 2    55878    2020-01-19        NaN                 0         NaN
# 3    55879    2020-01-26        7.0                 7         NaN
# 4    55880    2020-02-02        2.0                 9         NaN
# ..     ...           ...        ...               ...         ...
# 239  56115    2024-08-04        NaN         103436829       895.0
# 240  56116    2024-08-11        NaN         103436829       973.0
# 241  56117    2024-08-18        NaN         103436829       937.0
# 242  56118    2024-08-25        NaN         103436829       907.0
# 243  56119    2024-09-01        NaN         103436829       663.0
#
#      Cumulative_deaths  Month  Year
# 0                    0      1  2020
# 1                    0      1  2020
# 2                    0      1  2020
# ...

# %%
data.sort_values(by ='Date_reported')
# Out:
#      index Date_reported  New_cases  Cumulative_cases  New_deaths  \
# 0    55876    2020-01-05        NaN                 0         NaN
# 1    55877    2020-01-12        NaN                 0         NaN
# 2    55878    2020-01-19        NaN                 0         NaN
# 3    55879    2020-01-26        7.0                 7         NaN
# 4    55880    2020-02-02        2.0                 9         NaN
# ..     ...           ...        ...               ...         ...
# 239  56115    2024-08-04        NaN         103436829       895.0
# 240  56116    2024-08-11        NaN         103436829       973.0
# 241  56117    2024-08-18        NaN         103436829       937.0
# 242  56118    2024-08-25        NaN         103436829       907.0
# 243  56119    2024-09-01        NaN         103436829       663.0
#
#      Cumulative_deaths  Month  Year
# 0                    0      1  2020
# 1                    0      1  2020
# 2                    0      1  2020
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              244 non-null    int64
#  1   Date_reported      244 non-null    datetime64[ns]
#  2   New_cases          173 non-null    float64
#  3   Cumulative_cases   244 non-null    int64
#  4   New_deaths         236 non-null    float64
#  5   Cumulative_deaths  244 non-null    int64
#  6   Month              244 non-null    int32
#  7   Year               244 non-null    int32
# dtypes: datetime64[ns](1), float64(2), int32(2), int64(3)
# memory usage: 13.5 KB

# %%
import seaborn as sns
sns.boxplot(data = data,x ='Year',y = 'New_cases')
# Out:
# <Axes: xlabel='Year', ylabel='New_cases'>

# %%
#cleaning: step 3 of exploratory data analysis 
''' 1) handling missing data'''
df_usa_2021[pd.isnull(df_usa_2021)].count()
# Out:
# Date_reported        0
# Country_code         0
# Country              0
# Continent            0
# WHO_region           0
# New_cases            0
# Cumulative_cases     0
# New_deaths           0
# Cumulative_deaths    0
# Month                0
# Year                 0
# dtype: int64

# %%
df_usa_2021.describe()
# Out:
#              Date_reported     New_cases  Cumulative_cases    New_deaths  \
# count                   52  5.200000e+01      5.200000e+01     52.000000
# mean   2021-06-30 12:00:00  6.343926e+05      3.572202e+07   9032.057692
# min    2021-01-03 00:00:00  8.062700e+04      2.027144e+07   1509.000000
# 25%    2021-04-02 06:00:00  3.744200e+05      3.026967e+07   4452.500000
# 50%    2021-06-30 12:00:00  5.366360e+05      3.332038e+07   8179.500000
# 75%    2021-09-27 18:00:00  8.645535e+05      4.277397e+07  11803.000000
# max    2021-12-26 00:00:00  1.667151e+06      5.187886e+07  23312.000000
# std                    NaN  3.987708e+05      8.030842e+06   6099.374125
#
#        Cumulative_deaths      Month    Year
# count          52.000000  52.000000    52.0
# mean       612231.019231   6.461538  2021.0
# min        362570.000000   1.000000  2021.0
# 25%        555247.000000   3.750000  2021.0
# 50%        601179.500000   6.500000  2021.0
# ...

# %%
from scipy import stats
import statsmodels.api as sm
df_usa_2021['New_deaths'].hist()
# Out:
# <Axes: >

# %%
import seaborn as sns
# Plot Histogram
sns.histplot(data = df_usa_2021, x = "New_deaths", kde = True, hue = "Month")
# Out:
# <Axes: xlabel='New_deaths', ylabel='Count'>

# %%
sns.lineplot(x="Month", y="New_deaths", data=data) 
plt.show()

# %%
df_usa_2021['New_deaths'].describe()
# Out:
# count       52.000000
# mean      9032.057692
# std       6099.374125
# min       1509.000000
# 25%       4452.500000
# 50%       8179.500000
# 75%      11803.000000
# max      23312.000000
# Name: New_deaths, dtype: float64

# %%
df_usa_2021['z_score'] = stats.zscore(df_usa_2021['New_deaths'])
# Out:
# /var/folders/fq/fkp9z40x3h531t_m7kkc8dsc0000gn/T/ipykernel_9316/679008372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_usa_2021['z_score'] = stats.zscore(df_usa_2021['New_deaths'])

# %%
df_usa_2021[df_usa_2021['z_score']<-3.0]
# Out:
# Empty DataFrame
# Columns: [Date_reported, Country_code, Country, Continent, WHO_region, New_cases, Cumulative_cases, New_deaths, Cumulative_deaths, Month, Year, z_score]
# Index: []

# %%
df_usa_2021
# Out:
#       Date_reported Country_code                   Country      Continent  \
# 55928    2021-01-03           US  United States of America  North America
# 55929    2021-01-10           US  United States of America  North America
# 55930    2021-01-17           US  United States of America  North America
# 55931    2021-01-24           US  United States of America  North America
# 55932    2021-01-31           US  United States of America  North America
# 55933    2021-02-07           US  United States of America  North America
# 55934    2021-02-14           US  United States of America  North America
# 55935    2021-02-21           US  United States of America  North America
# 55936    2021-02-28           US  United States of America  North America
# 55937    2021-03-07           US  United States of America  North America
# 55938    2021-03-14           US  United States of America  North America
# 55939    2021-03-21           US  United States of America  North America
# ...

# %%
sample = df_usa_2021.sample(15,replace = True,random_state = 3578)

# %%
sample.reset_index()
# Out:
#     index Date_reported Country_code                   Country      Continent  \
# 0   55943    2021-04-18           US  United States of America  North America
# 1   55933    2021-02-07           US  United States of America  North America
# 2   55956    2021-07-18           US  United States of America  North America
# 3   55972    2021-11-07           US  United States of America  North America
# 4   55929    2021-01-10           US  United States of America  North America
# 5   55934    2021-02-14           US  United States of America  North America
# 6   55932    2021-01-31           US  United States of America  North America
# 7   55947    2021-05-16           US  United States of America  North America
# 8   55938    2021-03-14           US  United States of America  North America
# 9   55955    2021-07-11           US  United States of America  North America
# 10  55939    2021-03-21           US  United States of America  North America
# ...

# %%
sample = sample.sort_values(by='Month').reset_index()
sns.lineplot(x="Month", y="New_deaths", data=sample) 
plt.show()

# %%
sample
# Out:
#     index Date_reported Country_code                   Country      Continent  \
# 0   55929    2021-01-10           US  United States of America  North America
# 1   55932    2021-01-31           US  United States of America  North America
# 2   55933    2021-02-07           US  United States of America  North America
# 3   55934    2021-02-14           US  United States of America  North America
# 4   55938    2021-03-14           US  United States of America  North America
# 5   55939    2021-03-21           US  United States of America  North America
# 6   55943    2021-04-18           US  United States of America  North America
# 7   55947    2021-05-16           US  United States of America  North America
# 8   55956    2021-07-18           US  United States of America  North America
# 9   55955    2021-07-11           US  United States of America  North America
# 10  55960    2021-08-15           US  United States of America  North America
# ...

# %%
est_pop = df_usa_2021['New_deaths'].mean()
est_samp = sample['New_deaths'].mean()

# %%
print(est_pop , est_samp)
# Out:
# 9032.057692307691 9639.133333333333

# %%
est_list = []
for i in range(100):
    est_list.append([df_usa_2021['New_deaths'].sample(n = 50,replace =True),df_usa_2021['New_deaths'].sample(n = 50,replace =True).mean()])

# %%
est_list
# Out:
# [[55955     1509.0
#   55929    21497.0
#   55932    22249.0
#   55929    21497.0
#   55937    10446.0
#   55961     8055.0
#   55929    21497.0
#   55964    12085.0
#   55958     2927.0
#   55957     2084.0
#   55967    12992.0
#   55937    10446.0
#   55959     4453.0
#   55955     1509.0
#   55967    12992.0
#   55936    13360.0
#   55950     2675.0
#   55954     1717.0
#   55950     2675.0
#   55974    10276.0
#   55957     2084.0
#   55976     8304.0
#   55938     8559.0
#   55930    23312.0
#   55967    12992.0
#   55963    11709.0
#   55937    10446.0
#   55970    11091.0
#   55941     5352.0
#   55977     8586.0
#   55940     6111.0
#   55972     7407.0
#   55932    22249.0
#   55942     4903.0
#   55936    13360.0
#   55944     4721.0
#   55962    10183.0
#   55957     2084.0
#   55953     2101.0
#   55948     3624.0
#   55940     6111.0
#   55965    13590.0
#   55966    13384.0
#   55940     6111.0
#   55953     2101.0
#   55950     2675.0
#   55977     8586.0
# ...

# %%
mean = []
for i in range(100):
    mean.append(est_list[i][1])

# %%
mean
# Out:
# [6906.16,
#  9736.26,
#  8516.08,
#  7603.16,
#  9173.2,
#  10277.3,
#  9070.5,
#  9588.76,
#  8622.58,
#  9320.88,
#  7326.08,
#  10677.9,
#  8768.9,
#  10350.52,
#  9834.78,
#  10388.02,
#  8799.26,
#  9838.66,
#  10615.14,
#  8371.68,
#  8428.9,
#  8412.06,
#  8320.82,
#  8338.44,
#  10600.68,
#  9625.8,
#  8688.22,
#  9774.4,
#  8694.04,
#  9896.08,
#  9197.18,
#  9682.94,
#  9041.46,
#  8226.92,
#  8574.12,
#  8435.8,
#  9492.32,
#  7451.36,
#  8306.54,
#  7881.36,
#  7468.36,
#  8957.54,
#  9292.32,
#  7619.4,
#  8603.46,
#  9062.04,
#  8921.66,
#  10190.92,
#  7729.26,
#  9699.22,
#  8927.34,
#  10028.4,
#  8830.02,
#  8137.02,
#  9157.86,
#  8567.14,
#  9381.98,
#  9845.96,
#  9533.88,
#  7859.94,
#  7704.16,
#  10093.88,
#  9099.4,
#  8966.28,
#  8824.98,
#  7709.82,
#  8986.24,
#  10513.62,
#  8952.76,
#  9562.16,
#  7989.44,
#  9419.6,
#  8188.32,
#  9300.6,
#  7402.46,
#  8367.08,
#  8459.58,
#  10339.06,
#  10044.6,
#  9009.98,
#  9047.32,
#  9002.32,
#  8782.82,
# ...

# %%
sorted(mean)
# Out:
# [6906.16,
#  7326.08,
#  7393.84,
#  7402.46,
#  7451.36,
#  7468.36,
#  7531.42,
#  7603.16,
#  7619.4,
#  7704.16,
#  7709.82,
#  7729.26,
#  7859.94,
#  7881.36,
#  7923.02,
#  7989.44,
#  8137.02,
#  8188.32,
#  8226.92,
#  8306.54,
#  8320.82,
#  8338.44,
#  8367.08,
#  8371.68,
#  8412.06,
#  8428.9,
#  8435.8,
#  8459.58,
#  8516.08,
#  8567.14,
#  8574.12,
#  8603.46,
#  8622.58,
#  8642.74,
#  8652.22,
#  8653.2,
#  8688.22,
#  8694.04,
#  8768.9,
#  8782.82,
#  8799.26,
#  8824.98,
#  8830.02,
#  8921.66,
#  8927.34,
#  8952.76,
#  8957.54,
#  8966.28,
#  8972.84,
#  8983.54,
#  8986.24,
#  9002.32,
#  9009.98,
#  9041.46,
#  9047.32,
#  9062.04,
#  9070.5,
#  9092.8,
#  9099.4,
#  9157.86,
#  9173.2,
#  9185.54,
#  9197.18,
#  9292.32,
#  9298.2,
#  9300.6,
#  9320.88,
#  9381.98,
#  9419.6,
#  9492.32,
#  9533.88,
#  9562.16,
#  9588.76,
#  9625.8,
#  9682.94,
#  9699.22,
#  9736.26,
#  9774.4,
#  9793.58,
#  9829.62,
#  9834.78,
#  9838.66,
#  9845.96,
#  9896.08,
# ...

# %%
for i in range(100):
    if est_list[i][1] ==  9699.22:
        sam = est_list[i]

# %%
sam
# Out:
# [55974    10276.0
#  55952     1762.0
#  55969    10462.0
#  55979    11001.0
#  55938     8559.0
#  55964    12085.0
#  55971     8915.0
#  55965    13590.0
#  55955     1509.0
#  55975     5690.0
#  55958     2927.0
#  55959     4453.0
#  55933    20100.0
#  55953     2101.0
#  55946     4451.0
#  55948     3624.0
#  55961     8055.0
#  55965    13590.0
#  55961     8055.0
#  55956     1931.0
#  55978     9065.0
#  55948     3624.0
#  55950     2675.0
#  55952     1762.0
#  55934    19838.0
#  55979    11001.0
#  55962    10183.0
#  55967    12992.0
#  55977     8586.0
#  55954     1717.0
#  55969    10462.0
#  55938     8559.0
#  55930    23312.0
#  55970    11091.0
#  55957     2084.0
#  55957     2084.0
#  55951     2624.0
#  55976     8304.0
#  55959     4453.0
#  55951     2624.0
#  55951     2624.0
#  55939     6264.0
#  55954     1717.0
#  55930    23312.0
#  55966    13384.0
#  55956     1931.0
#  55950     2675.0
#  55959     4453.0
#  55967    12992.0
#  55943     4875.0
# ...
